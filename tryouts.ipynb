# %%
from trainer import Trainer

tr = Trainer(data_dir="./data_indi/stocks")
tr.train(dir_name="./experiments/v3",stock_names=["A","AA","AACG"], descriptors = ["Open","RSI_signal","MA_signal"],max_steps=100,save=True)
# Out:
# 2025-11-30 01:07:57.941392: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Action dimension=12
# 2025-11-30 01:08:22.487245: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Episode 2: Score:2964637.5

# %%
from trainer import Trainer

#tr = Trainer(data_dir="./data/stocks")
tr = Trainer(data_dir="./data_indi/stocks")
tr.train(dir_name="./experiments/states",stock_names=["A","AA","AACG"], descriptors = ["Open","RSI_signal","MA_signal"],max_steps=10,init_cash=10000, save=True)
# Out:
# 2025-11-26 01:11:46.229860: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Action dimension=18
# 2025-11-26 01:12:08.302268: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Episode 2: Score:2807631.0

# %%
from trainer import Trainer

#tr = Trainer(data_dir="./data/stocks")
tr = Trainer(data_dir="./data_indi/stocks")

tree = tr.fQi_extremeTree(T=2,save_dir="./experiments/tree1", init_cash=10000,stock_names=["A","AA"], descriptors = ["Open","RSI_signal","MA_signal"])
# Out:
# 2025-11-30 15:25:47.205817: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# {'[0, 0]': 0, '[0, 1]': 1, '[0, 2]': 2, '[0, 3]': 3, '[1, 0]': 4, '[1, 1]': 5, '[1, 2]': 6, '[1, 3]': 7, '[2, 0]': 8, '[2, 1]': 9, '[2, 2]': 10, '[2, 3]': 11, '[3, 0]': 12, '[3, 1]': 13, '[3, 2]': 14, '[3, 3]': 15}
# Chyba pri zápise do súboru: [Errno 2] No such file or directory: './experiments/tree1/states.json'

# %%
from inference import Trader
trader = Trader(init_cash=1000, descriptors = ["Open","RSI_signal","MA_signal"],stock_names=["A","AA"], validation_data_path="./data_indi/stocks", results_dir="./validations/tree1")

tree_model = trader.load_tree(file_path="./experiments/tree/tree_model.joblib")
trader.set_tree_aproximator(tree_model)
trader.trade()
